# %% [markdown]
# ## 1. Histogram Stretching

# %% [markdown]
# 1) 제시된 LUT(look up table)을 생성하시오. (모든 LUT은 uint8의 형태로 저장하시오)
# LUT1: 𝑦 = 2𝑥
# LUT2: 𝑦 = (1/2)𝑥
# LUT3: 𝑦 = −𝑥+255
# LUT4: 0 <= 𝑥 <= 96,  𝑦=32
#  96
#  96 < 𝑥 <= 200, 𝑦=192−32
#  200−96
#  𝑥
# (𝑥 −96)+32
# 200 < 𝑥 <= 255, 𝑦=255−192
#  255−200
#  (𝑥 −200)+192

# %%
import skimage.io as io
import numpy as np
import matplotlib.pyplot as plt

arr = np.arange(256) # [0, ..., 255]

lut1 = np.uint8(np.clip(arr*2,0,255))
lut2 = np.uint8(np.clip(arr*0.5,0,255))
lut3 = np.uint8(np.clip(arr*-1 +255,0,255))

t1 = 0.33335*np.arange(97)
t2 = ((192-32)*(np.arange(97,201)-96)/(200-96))+32
t3 = ((255-192)*(np.arange(201,256)-200)/(255-200))+192
lut4 = np.uint8(np.floor(np.concatenate((t1,t2,t3))))


#t1 = 0.33335*arr(97)
#t2 = {(192-32)*(arr(97,201)-96)/(200-96)}+32
#t3 = {(255-192)*(arr(201,256)-200)/(255-200)}+192
#lut4 = np.uint8(np.floor(np.concatenate(t1,t2,t3)))

plt.subplot(1,4,1)
plt.plot(lut1)
plt.xlim([0, 255])
plt.ylim([0, 255])
plt.subplot(1,4,2)
plt.plot(lut2)
plt.xlim([0, 255])
plt.ylim([0, 255])
plt.subplot(1,4,3)
plt.plot(lut3)
plt.xlim([0, 255])
plt.ylim([0, 255])
plt.subplot(1,4,4)
plt.plot(lut4)
plt.xlim([0, 255])
plt.ylim([0, 255])
# Out:
# (0.0, 255.0)

# %% [markdown]
# 2) 1)에서 생성한 LUT 4개를 하나의 figure에 출력하시오.(subplot)

# %%
im = plt.imread('images\lena.bmp')
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# 3) 1)에서 생성한 LUT을 이용해서 영상을 변환하시오.
# ###### (a) function Image_Adjust_LUT(a,b)를 만드시오.
# ###### Input parameters: a: input image, b: LUT
# ###### Output: returns adjusted image
#
# ###### (b) 영상 ‘x-ray.png’를 읽으시오.
#
#
# ###### (c) function Image_Adjust_LUT를 이용해서 읽어들인 x-ray LUT1, 2, 3, 4를 이용하여 변환하시오
#
#
# ###### (d) (c) 에서 변환한 4개의 이미지를 하나의 figure에 출력하시오. (subplot(), imshow())

# %% [markdown]
# ## 2. Histogram Equalization
